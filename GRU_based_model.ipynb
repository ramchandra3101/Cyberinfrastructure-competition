# %%
import h5py
import numpy as np
from datetime import datetime
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, GRU, Dense, Reshape, Dropout
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
with h5py.File('/Users/rcyerramsetti/Desktop/Semester-2/Cyberinfra competition/Data/TrainingData.h5', 'r') as f:
    
    traffic_data = f['trip'][()]
    dates = f['timeslot'][()]

# %%
formatted_dates = []

for date_string in dates:
    formatted_date = datetime.strptime(date_string.decode(), '%Y%m%d%H%M')

    year = formatted_date.year
    month = formatted_date.month
    day = formatted_date.day
    hour = formatted_date.hour
    minute = formatted_date.minute

    formatted_dates.append(np.array([year, month, day, hour, minute]))

formatted_dates = np.array(formatted_dates).reshape(1488, 5, 1)

# %%
formatted_dates[0]
# Out:
# array([[2019],
#        [  10],
#        [   1],
#        [   0],
#        [  30]])

# %%
test_size = 240

train_traffic_data = traffic_data[:-test_size]
test_traffic_data = traffic_data[-test_size:]

train_formatted_dates = formatted_dates[:-test_size]
test_formatted_dates = formatted_dates[-test_size:]

# %%
train_formatted_dates[0]
# Out:
# array([[2019],
#        [  10],
#        [   1],
#        [   0],
#        [  30]])

# %%
X_train, X_test = train_formatted_dates, test_formatted_dates
y_train, y_test = train_traffic_data, test_traffic_data

# %%
model = Sequential()


model.add(GRU(50, activation='relu', input_shape=(5, 1))) 
model.add(Dropout(0.2))
model.add(Dense(2 * 16 * 8, activation='linear'))
model.add(Reshape((2, 16, 8)))
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse')

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint = ModelCheckpoint('GRU_init_model.keras', monitor='val_loss', save_best_only=True)

# %%
model.fit(X_train, y_train, epochs=50, batch_size=44, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 29/29 [==============================] - 1s 7ms/step - loss: 679.1400 - val_loss: 187.3797
# Epoch 2/50
# 29/29 [==============================] - 0s 2ms/step - loss: 218.1864 - val_loss: 96.8991
# Epoch 3/50
# 29/29 [==============================] - 0s 2ms/step - loss: 150.1664 - val_loss: 84.8685
# Epoch 4/50
# 29/29 [==============================] - 0s 3ms/step - loss: 130.0422 - val_loss: 74.0063
# Epoch 5/50
# 29/29 [==============================] - 0s 3ms/step - loss: 116.4035 - val_loss: 72.8291
# Epoch 6/50
# 29/29 [==============================] - 0s 3ms/step - loss: 105.1732 - val_loss: 69.7071
# Epoch 7/50
# 29/29 [==============================] - 0s 4ms/step - loss: 99.3133 - val_loss: 82.9835
# Epoch 8/50
# 29/29 [==============================] - 0s 4ms/step - loss: 94.1830 - val_loss: 72.5644
# Epoch 9/50
# 29/29 [==============================] - 0s 3ms/step - loss: 92.9631 - val_loss: 63.2385
# Epoch 10/50
# 29/29 [==============================] - 0s 3ms/step - loss: 85.8853 - val_loss: 67.7147
# Epoch 11/50
# 29/29 [==============================] - 0s 3ms/step - loss: 84.9929 - val_loss: 66.8598
# Epoch 12/50
# 29/29 [==============================] - 0s 4ms/step - loss: 82.4877 - val_loss: 68.0498
# Epoch 13/50
# 29/29 [==============================] - 0s 3ms/step - loss: 83.3323 - val_loss: 60.3177
# Epoch 14/50
# 29/29 [==============================] - 0s 3ms/step - loss: 77.0916 - val_loss: 61.9549
# Epoch 15/50
# 29/29 [==============================] - 0s 3ms/step - loss: 76.3182 - val_loss: 61.0591
# Epoch 16/50
# 29/29 [==============================] - 0s 3ms/step - loss: 77.6946 - val_loss: 60.0894
# Epoch 17/50
# 29/29 [==============================] - 0s 3ms/step - loss: 72.7738 - val_loss: 60.9617
# Epoch 18/50
# 29/29 [==============================] - 0s 3ms/step - loss: 73.6258 - val_loss: 70.1062
# Epoch 19/50
# 29/29 [==============================] - 0s 3ms/step - loss: 71.8790 - val_loss: 58.3497
# Epoch 20/50
# 29/29 [==============================] - 0s 3ms/step - loss: 71.9056 - val_loss: 68.4005
# Epoch 21/50
# 29/29 [==============================] - 0s 3ms/step - loss: 72.0221 - val_loss: 57.1253
# Epoch 22/50
# 29/29 [==============================] - 0s 3ms/step - loss: 65.6873 - val_loss: 57.5111
# Epoch 23/50
# 29/29 [==============================] - 0s 3ms/step - loss: 80.4885 - val_loss: 65.6070
# Epoch 24/50
# 29/29 [==============================] - 0s 3ms/step - loss: 79.3300 - val_loss: 69.2067
# Epoch 25/50
# 29/29 [==============================] - 0s 3ms/step - loss: 85.3838 - val_loss: 63.7840
# Epoch 26/50
# 29/29 [==============================] - 0s 3ms/step - loss: 81.4993 - val_loss: 62.9533
# Epoch 27/50
# 29/29 [==============================] - 0s 3ms/step - loss: 76.2067 - val_loss: 60.6239
# Epoch 28/50
# 29/29 [==============================] - 0s 3ms/step - loss: 74.8865 - val_loss: 58.0800
# Epoch 29/50
# 29/29 [==============================] - 0s 3ms/step - loss: 73.2261 - val_loss: 59.2357
# Epoch 30/50
# 29/29 [==============================] - 0s 3ms/step - loss: 72.0448 - val_loss: 59.9429
# Epoch 31/50
# 29/29 [==============================] - 0s 3ms/step - loss: 72.4976 - val_loss: 58.8960
# Epoch 32/50
# 29/29 [==============================] - 0s 3ms/step - loss: 68.1363 - val_loss: 58.7662
# Epoch 33/50
# 29/29 [==============================] - 0s 3ms/step - loss: 69.3270 - val_loss: 56.3194
# Epoch 34/50
# 29/29 [==============================] - 0s 3ms/step - loss: 72.1057 - val_loss: 58.2452
# Epoch 35/50
# 29/29 [==============================] - 0s 3ms/step - loss: 95.3067 - val_loss: 99.6247
# Epoch 36/50
# 29/29 [==============================] - 0s 3ms/step - loss: 107.1799 - val_loss: 71.6435
# Epoch 37/50
# 29/29 [==============================] - 0s 3ms/step - loss: 93.8653 - val_loss: 77.4297
# Epoch 38/50
# 29/29 [==============================] - 0s 3ms/step - loss: 89.3257 - val_loss: 68.1483
# Epoch 39/50
# 29/29 [==============================] - 0s 3ms/step - loss: 87.2956 - val_loss: 72.8426
# Epoch 40/50
# 29/29 [==============================] - 0s 3ms/step - loss: 86.0950 - val_loss: 80.9051
# Epoch 41/50
# 29/29 [==============================] - 0s 3ms/step - loss: 82.2975 - val_loss: 64.9536
# Epoch 42/50
# 29/29 [==============================] - 0s 3ms/step - loss: 82.9042 - val_loss: 66.5845
# Epoch 43/50
# 29/29 [==============================] - 0s 4ms/step - loss: 80.7833 - val_loss: 64.5066
# Epoch 44/50
# 29/29 [==============================] - 0s 3ms/step - loss: 80.1745 - val_loss: 65.5334
# Epoch 45/50
# 29/29 [==============================] - 0s 3ms/step - loss: 78.6544 - val_loss: 63.9183
# Epoch 46/50
# 29/29 [==============================] - 0s 3ms/step - loss: 78.5607 - val_loss: 63.3188
# Epoch 47/50
# 29/29 [==============================] - 0s 4ms/step - loss: 77.8101 - val_loss: 63.7670
# Epoch 48/50
# 29/29 [==============================] - 0s 4ms/step - loss: 73.9984 - val_loss: 73.5335
# Epoch 49/50
# 29/29 [==============================] - 0s 3ms/step - loss: 75.1676 - val_loss: 63.3819
# Epoch 50/50
# 29/29 [==============================] - 0s 3ms/step - loss: 74.2409 - val_loss: 60.5151

# %%
mse = model.evaluate(X_test, y_test)


rmse = np.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')
# Out:
# 8/8 [==============================] - 0s 1ms/step - loss: 60.5151
# Root Mean Squared Error: 7.779144860270959

# %%
model.save('GRU_model.keras')

# %%
new_model = load_model('GRU_model.keras')

mse = new_model.evaluate(X_test, y_test)


rmse = np.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')
# Out:
# 8/8 [==============================] - 0s 1ms/step - loss: 60.5151
# Root Mean Squared Error: 7.779144860270959

# %%
y_pred = model.predict(x=X_test)
y_pred.shape
#print(y_pred[0], y_test[0])
# Out:
# 6/6 [==============================] - 0s 973us/step
# (172, 2, 16, 8)

# %%
import matplotlib.pyplot as plt
import numpy as np  

data = y_pred[:10]  
fig, axs = plt.subplots(len(data), 2, figsize=(10, 2 * len(data)))

for i, (matrix1, matrix2) in enumerate(data):
    if len(data) == 1:
        ax1, ax2 = axs
    else:
        ax1, ax2 = axs[i, 0], axs[i, 1]
    ax1.imshow(matrix1, cmap='hot', interpolation='nearest')
    ax1.set_title(f'Value {i+1} - Matrix 1')
    ax2.imshow(matrix2, cmap='hot', interpolation='nearest')
    ax2.set_title(f'Value {i+1} - Matrix 2')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = y_pred  
data1=y_test
mean_values1 = [int(np.mean(matrix1)) for matrix1,matrix2 in data]
mean_values2 = [int(np.mean(matrix1)) for matrix1,matrix2 in data1]
x_values = range(1, len(data) + 1)
plt.figure(figsize=(10, 5))
plt.plot(x_values, mean_values1, label='Mean of Matrix y_pred', marker='o')
plt.plot(x_values, mean_values2, label='Mean of Matrix y_test', marker='o')
plt.title('Mean Value of Matrices')
plt.xlabel('Value Index')
plt.ylabel('Mean')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = y_pred  # Adjust the number here to select the first N values you want to plot
data1=y_test
# Calculate statistics for each matrix pair
mean_values1 = [int(np.mean(matrix2)) for matrix1, matrix2 in data]
mean_values2 = [np.mean(matrix2) for matrix1, matrix2 in data1]
#print(mean_values1,mean_values2)
# Create a range of indices for the x-axis
x_values = range(1, len(data) + 1)

# Create the plot
plt.figure(figsize=(10, 5))

# Plot the mean of the first matrix in each pair
plt.plot(x_values, mean_values1, label='Mean of Matrix y_pred', marker='o')

# Plot the mean of the second matrix in each pair
plt.plot(x_values, mean_values2, label='Mean of Matrix y_test', marker='o')

# Add title and labels
plt.title('Mean Value of Matrices')
plt.xlabel('Value Index')
plt.ylabel('Mean')

# Add a legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
for matrix1,matrix2 in data:
    #print(matrix1)
    print(matrix1.shape)
# Out:
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
# (16, 8)
